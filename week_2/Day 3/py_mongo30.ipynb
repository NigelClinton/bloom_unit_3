# %%
#import mongo library 
import pymongo

# %%
# # connect to the mongodb cluster
# USER = 'pmuserds30'
# PASSWORD = 'Livelife1995'
# DBNAME = 'test'

client = pymongo.MongoClient("mongodb+srv://pmuserds30:<password>@cluster0.i3uoh.mongodb.net/myFirstDatabase?retryWrites=true&w=majority".format(USER,PASSWORD,DBNAME))
db = client.test

# %%
#Establish connection then assign it to a variable
client = pymongo.MongoClient("mongodb+srv://pmuserds30:Livelife1995@cluster0.i3uoh.mongodb.net/test?retryWrites=true&w=majority")

# %%
#Confirm connection
client
# Out:
# MongoClient(host=['cluster0-shard-00-02.i3uoh.mongodb.net:27017', 'cluster0-shard-00-01.i3uoh.mongodb.net:27017', 'cluster0-shard-00-00.i3uoh.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-oe5wv7-shard-0', ssl=True)

# %%
#assign the DB
db = client.test

# %%
#View directory of db.test
dir(db.test)

# %%
#print dir of db test
print(dir(db.test))

# %%
#Information regarding db.test
help(db.test)

# %%
#information regarding the insert one fucntion
help(db.test.insert_one)

# %%
#information regarding the insert_many function
help(db.test.insert_many)

# %%
#Inserting a value into the test db
db.test.insert_one({'p': 2})

# %%
#information regarding count_documents
help(db.test.count_documents)

# %%
#count documents for the inserted row
db.test.count_documents({'p':2})
# Out:
# 2

# %%
#information regarding the find function
help(db.test.find)

# %%
#
db.test.find_one({'x': 1})

# %%
#Collection names for the db to display tables
db.list_collection_names()
# Out:
# ['test', 'test_db', 'armory_item_2']

# %%
#assigning information in dict format to be added to the db
book = {
    "title": "my favorite book",
    "author": "my favorite author",
    "like": "yes"
}

song = {
    "name": "my favorite song",
    "singer": "my favorite singer",
    "like": "no"
}

# %%
#assigning your tables
docs = [book,song]

# %%
#insert table function for multiple tables
db.test_db.insert_many(docs)

# %%
#listing all information pertaining to the two tables
list(db.test_db.find())

# %%
#import function
import sqlite3

# %%
#Assigning the connection to a variable then establishing it
s_conn = sqlite3.connect('rpg_db.sqlite3')

# %%
#creating a cusror
s_cur = s_conn.cursor()

# %%
#assigning the rows from the armory item table
rows = s_cur.execute("SELECT name,value,weight FROM armory_item;").fetchall()
print(rows)
# Out:
# [('Libero facere dolore, as', 0, 0), ('Qui', 0, 0), ('Laborios', 0, 0), ('Quibusdam illo deserunt ea', 0, 0), ('Quod eveniet i', 0, 0), ('Qui odio beata', 0, 0), ('Omnis', 0, 0), ('Saepe ea vo', 0, 0), ('Vel illo sed', 0, 0), ('Pariatur hic iste m', 0, 0), ('Eum illo expedita', 0, 0), ('Laudantium recusand', 0, 0), ('Molesti', 0, 0), ('Veniam fuga n', 0, 0), ('Animi molestias possimus nihil', 0, 0), ('Assu', 0, 0), ('Officiis', 0, 0), ('Consectetur deleniti cupi', 0, 0), ('Explicabo', 0, 0), ('Dolores rem v', 0, 0), ('Sit rerum err', 0, 0), ('Sapiente numquam qu', 0, 0), ('Nam ab illum culpa corporis fu', 0, 0), ('Blanditiis obcaecat', 0, 0), ('Ex', 0, 0), ('Assumenda nam i', 0, 0), ('Distinctio mini', 0, 0), ('Impedit libero id modi eos vol', 0, 0), ('In p', 0, 0), ('Possimus quae elig', 0, 0), ('Vitae nulla praesentium magnam', 0, 0), ('Ipsam placeat e', 0, 0), ('Corporis ani', 0, 0), ('Eius cum quis', 0, 0), ('Suscip', 0, 0), ('Soluta consequatur dolore', 0, 0), ('Perferendis corr
# ...

# %%
#Desciption for each value
s_cur.description
# Out:
# (('name', None, None, None, None, None, None),
#  ('value', None, None, None, None, None, None),
#  ('weight', None, None, None, None, None, None))

# %%
#List comprehention for columns in table
columns = [d[0] for d in s_cur.description]

# %%
#preview of variable created above
columns
# Out:
# ['name', 'value', 'weight']

# %%
#for loop to import the data into a list
armory_item_doc = []
for row in rows:
    armory_item_doc.append(dict(zip(columns,row)))

# %%
#table preview from for loop above
armory_item_doc
# Out:
# [{'name': 'Libero facere dolore, as', 'value': 0, 'weight': 0},
#  {'name': 'Qui', 'value': 0, 'weight': 0},
#  {'name': 'Laborios', 'value': 0, 'weight': 0},
#  {'name': 'Quibusdam illo deserunt ea', 'value': 0, 'weight': 0},
#  {'name': 'Quod eveniet i', 'value': 0, 'weight': 0},
#  {'name': 'Qui odio beata', 'value': 0, 'weight': 0},
#  {'name': 'Omnis', 'value': 0, 'weight': 0},
#  {'name': 'Saepe ea vo', 'value': 0, 'weight': 0},
#  {'name': 'Vel illo sed', 'value': 0, 'weight': 0},
#  {'name': 'Pariatur hic iste m', 'value': 0, 'weight': 0},
#  {'name': 'Eum illo expedita', 'value': 0, 'weight': 0},
#  {'name': 'Laudantium recusand', 'value': 0, 'weight': 0},
#  {'name': 'Molesti', 'value': 0, 'weight': 0},
#  {'name': 'Veniam fuga n', 'value': 0, 'weight': 0},
#  {'name': 'Animi molestias possimus nihil', 'value': 0, 'weight': 0},
#  {'name': 'Assu', 'value': 0, 'weight': 0},
#  {'name': 'Officiis', 'value': 0, 'weight': 0},
# ...

# %%
#insert many to populate the table
db.armory_item.insert_many(armory_item_doc)

# %%
#list to see the table created above
list(db.armory_item.find())
# Out:
# [{'_id': ObjectId('613a6306f2c86444d22c1013'),
#   'name': 'Libero facere dolore, as',
#   'value': 0,
#   'weight': 0},
#  {'_id': ObjectId('613a6306f2c86444d22c1014'),
#   'name': 'Qui',
#   'value': 0,
#   'weight': 0},
#  {'_id': ObjectId('613a6306f2c86444d22c1015'),
#   'name': 'Laborios',
#   'value': 0,
#   'weight': 0},
#  {'_id': ObjectId('613a6306f2c86444d22c1016'),
#   'name': 'Quibusdam illo deserunt ea',
#   'value': 0,
#   'weight': 0},
#  {'_id': ObjectId('613a6306f2c86444d22c1017'),
#   'name': 'Quod eveniet i',
#   'value': 0,
#   'weight': 0},
#  {'_id': ObjectId('613a6306f2c86444d22c1018'),
#   'name': 'Qui odio beata',
#   'value': 0,
#   'weight': 0},
#  {'_id': ObjectId('613a6306f2c86444d22c1019'),
#   'name': 'Omnis',
#   'value': 0,
#   'weight': 0},
#  {'_id': ObjectId('613a6306f2c86444d22c101a'),
#   'name': 'Saepe ea vo',
#   'value': 0,
#   'weight': 0},
#  {'_id': ObjectId('613a6306f2c86444d22c101b'),
#   'name': 'Vel illo sed',
#   'value': 0,
# ...

# %%
#DB collection names 
db.list_collection_names()
# Out:
# ['test', 'test_db', 'armory_item_2', 'armory_item']

# %%
#assigning the rows from the charactercreator_character_inventory
rows = s_cur.execute("SELECT * FROM charactercreator_character_inventory;").fetchall()

#List comprehention for creating columns in table
columns = [d[0] for d in s_cur.description]

#for loop to import the data into a list
charactercreator_character_inventory_doc = []
for row in rows:
    charactercreator_character_inventory_doc.append(dict(zip(columns,row)))

#insert many to populate the table
db.character_inventory.insert_many(charactercreator_character_inventory_doc)

# %%
charactercreator_character_inventory_doc
# Out:
# [{'id': 1,
#   'character_id': 1,
#   'item_id': 58,
#   '_id': ObjectId('613a635cf2c86444d22c10c1')},
#  {'id': 2,
#   'character_id': 1,
#   'item_id': 20,
#   '_id': ObjectId('613a635cf2c86444d22c10c2')},
#  {'id': 3,
#   'character_id': 1,
#   'item_id': 85,
#   '_id': ObjectId('613a635cf2c86444d22c10c3')},
#  {'id': 4,
#   'character_id': 2,
#   'item_id': 115,
#   '_id': ObjectId('613a635cf2c86444d22c10c4')},
#  {'id': 5,
#   'character_id': 2,
#   'item_id': 93,
#   '_id': ObjectId('613a635cf2c86444d22c10c5')},
#  {'id': 6,
#   'character_id': 2,
#   'item_id': 133,
#   '_id': ObjectId('613a635cf2c86444d22c10c6')},
#  {'id': 7,
#   'character_id': 3,
#   'item_id': 8,
#   '_id': ObjectId('613a635cf2c86444d22c10c7')},
#  {'id': 8,
#   'character_id': 3,
#   'item_id': 43,
#   '_id': ObjectId('613a635cf2c86444d22c10c8')},
#  {'id': 9,
#   'character_id': 4,
#   'item_id': 82,
#   '_id': ObjectId('613a635cf2c86444d22c10c9')},
#  {'id': 10,
#   'character_id': 4,
# ...

# %%
## charactercreator_character TABLE ##

#assigning the rows from the armory weapon table
rows = s_cur.execute("SELECT * FROM charactercreator_character;").fetchall()

#List comprehention for creating columns in table
columns = [d[0] for d in s_cur.description]

#for loop to import the data into a list
charactercreator_character_doc = []
for row in rows:
    charactercreator_character_doc.append(dict(zip(columns,row)))

#insert many to populate the table
db.character.insert_many(charactercreator_character_doc)

# %%
charactercreator_character_doc
# Out:
# [{'character_id': 1,
#   'name': 'Aliquid iste optio reiciendi',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1,
#   '_id': ObjectId('613a6462f2c86444d22c1443')},
#  {'character_id': 2,
#   'name': 'Optio dolorem ex a',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1,
#   '_id': ObjectId('613a6462f2c86444d22c1444')},
#  {'character_id': 3,
#   'name': 'Minus c',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1,
#   '_id': ObjectId('613a6462f2c86444d22c1445')},
#  {'character_id': 4,
#   'name': 'Sit ut repr',
#   'level': 0,
#   'exp': 0,
#   'hp': 10,
#   'strength': 1,
#   'intelligence': 1,
#   'dexterity': 1,
#   'wisdom': 1,
#   '_id': ObjectId('613a6462f2c86444d22c1446')},
#  {'character_id': 5,
#   'name': 'At id recusandae expl',
#   'level': 0,
# ...
